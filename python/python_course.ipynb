# %% [markdown]
# Faça um programa que peça ao usuário para digitar um número inteiro,
# informe se este número é par ou impar. Caso o usuário não digite um número inteiro, informe que não é um número inteiro

# %%
def det_int(numero_inteiro):
  if numero_inteiro.isdigit():
    numero_inteiro = int(numero_inteiro)
    if numero_inteiro % 2 == 0:
       return print('Esse número é par')
    else:
       return print('Esse número é impar') 
  
  else:
    return print('Isso não é um número.')

# %%
numero_inteiro = input('Digite um número inteiro: ')
det_int(numero_inteiro)
# Out:
# Digite um número inteiro: a
# Isso não é um número.

# %% [markdown]
# Formatando valores com modificadores
#
#
# *   :s - texto (strings)
# *   :d - inteiros (int)
# * :f - Númeos de ponto flutuante (float)
# * :.(numero)f - Quantidade de casas decimais (float)
# * :(CARACTERE)(> OU < OU ^)(QUANTIDADE)(TIPO - s,d ou f)

# %%
num_1 = 2

# %%
num_2 = 3

# %%
divisão = num_1/num_2

# %%
print('{:.12f}'.format(divisão))
# Out:
# 0.666666666667

# %%
print('{:0^11}'.format(num_1))
# Out:
# 00000200000

# %%
nome = 'Gabriel'
sobrenome = 'Eninger'
nome_formatado = '{0:#^10}{1:#^9}'.format(nome,sobrenome)

print(nome_formatado)
# Out:
# #Gabriel###Eninger#

# %% [markdown]
# # Índices e fatiamento de strings em python

# %%
texto = 'Python s2'

# %% [markdown]
# você pode chamar catacteres especificos por meio de seu indice

# %%
print(texto[2])
# Out:
# t

# %% [markdown]
# se utiliza ' : ' para estabelecer um corte da string

# %%
print(texto[:-1])
# Out:
# Python s

# %% [markdown]
# o terceiro define de quantos em quantos espaços o caractere vai ser printado

# %%
print(texto)
print(texto[0::1])
print(texto[0::2])
print(texto[0::3])
# Out:
# Python s2
# Python s2
# Pto 2
# Ph

# %% [markdown]
# # Estrutrutura de repetição em python com while
# realiza uma ação enquanto uma condição for cumprida

# %%
x = 0

while x < 3:
    if x == 2:
        x = x+1
        continue
    print(x)
    x = x+1
# Out:
# 0
# 1

# %% [markdown]
# calculadora básica

# %%
while True:
    print()
    num_1 = input('Digite um Numero: ')
    num_2 = input('Digite outro número: ')
    operador = input('Digite um operador: ')

    if not num_1.isnumeric() or num_2.isnumeric():
        ('caractere fornecido não é um número')
        continue
    
    num_1 = int(num_2)
    num_2 = int(num_2)

    #operadores

    if operador == '+':
        print(num_1+num_2)
    elif operador == '-':
        print(num_1-num_2)
    elif operador == '/':
        print(num_1/num_2)
    elif operador == '*':
        print(num_1*num_2)
    else:
        print('operador oferecido não optimal')
    break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\GEOLIV~1\AppData\Local\Temp/ipykernel_13516/2255488005.py in <module>
#       2     print()
#       3     num_1 = input('Digite um Numero: ')
# ----> 4     num_2 = input('Digite outro número: ')
#       5     operador = input('Digite um operador: ')
#       6
#
# c:\Users\geoliveira\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# c:\Users\geoliveira\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
# ...

# %% [markdown]
# #  while / else : contadores e acumuladores

# %%
#while realizara a tarefa definida até se tornar falsa, então o else é executado

contador = 0
acumulador = 0 

while contador < 3:
    print(contador)

    acumulador = contador + acumulador
    contador += 1

else:
    print('Cheguei no else')
# Out:
# 0
# 1
# 2
# Cheguei no else

# %% [markdown]
# # for - estrututura de repetição

# %%
for n in range(0, 10, 3):
    print(n)
# Out:
# 0
# 3
# 6
# 9

# %%
texto = 'Python'
nova_string = ''

for letra in texto:
    if letra == 't':
        nova_string = nova_string + letra.upper()
    elif letra == 'h':
        nova_string += letra.upper()
        continue
    else:
        nova_string += letra

print(nova_string)
# Out:
# PyTHon
